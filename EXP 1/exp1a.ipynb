# %%
print("Welcome to Data Analytics Lab")
print("Air Quality Data Analysis")
# Out:
# Welcome to Data Analytics Lab
# Air Quality Data Analysis

# %%
a = 20
b = 10

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
# Out:
# Addition = 30
# Subtraction = 10
# Multiplication = 200
# Division = 2.0

# %%
dataset_name = "City Day Air Quality Dataset"
domain = "Air Quality Analytics"
records = 29531
columns = 16

print("Dataset:", dataset_name)
print("Domain:", domain)
print("Records:", records)
print("Columns:", columns)
# Out:
# Dataset: City Day Air Quality Dataset
# Domain: Air Quality Analytics
# Records: 29531
# Columns: 16

# %%
# Air Quality Data Analytics

## Experiment 1

### Jupyter Notebook

### City Day Dataset

# %%
import numpy as np

aqi_values = np.array([50, 100, 150, 200, 250])

print(aqi_values)
print("Mean AQI =", np.mean(aqi_values))
print("Maximum AQI =", np.max(aqi_values))
print("Minimum AQI =", np.min(aqi_values))
# Out:
# [ 50 100 150 200 250]
# Mean AQI = 150.0
# Maximum AQI = 250
# Minimum AQI = 50

# %%
import pandas as pd

df = pd.read_csv("city_day.csv")

print(df.head())
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
import pandas as pd

df = pd.read_csv("city_day.csv")

print("Number of Rows =", df.shape[0])
print("Number of Columns =", df.shape[1])
print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Number of Rows = 29531
# Number of Columns = 16
#
# Column Names:
# ['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']

# %%
import pandas as pd

df = pd.read_csv("city_day.csv")

aqi = df["AQI"].dropna()

print("Average AQI =", aqi.mean())
print("Maximum AQI =", aqi.max())
print("Minimum AQI =", aqi.min())
# Out:
# Average AQI = 166.4635814889336
# Maximum AQI = 2049.0
# Minimum AQI = 13.0

# %%
import pandas as pd

df = pd.read_csv("city_day.csv")

aqi = df["AQI"].dropna()

print("Average AQI =", aqi.mean())
print("Maximum AQI =", aqi.max())
print("Minimum AQI =", aqi.min())
# Out:
# Average AQI = 166.4635814889336
# Maximum AQI = 2049.0
# Minimum AQI = 13.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("city_day.csv")

city_aqi = df.groupby("City")["AQI"].mean().sort_values(ascending=False).head(10)

city_aqi.plot(kind="bar")

plt.title("Top 10 Cities by Average AQI")
plt.xlabel("City")
plt.ylabel("Average AQI")

plt.xticks(rotation=45)
plt.show()
